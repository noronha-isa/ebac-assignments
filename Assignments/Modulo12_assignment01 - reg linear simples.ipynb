# %% [markdown]
# # Regressão 01 - tarefa 01

# %% [markdown]
# ### 1. Explorando a base de gorjetas
#
# a. Na aula fizemos uma regressão de ```tip``` explicada por ```net_bill```. Carregue os pacotes e a base, crie as variáveis necessárias como na aula, e reproduza esta regressão.
#
# b. Reproduza também o gráfico de dispersão dessas duas variáveis.

# %%
# Carregando pacotes e a base

import pandas as pd
import seaborn as sns
from seaborn import load_dataset

import matplotlib.pyplot as plt

import numpy as np

import statsmodels.formula.api as smf

# %%
tips = sns.load_dataset("tips")
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips['net_bill'] = tips['total_bill'] - tips['tip']
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct  net_bill
# 26        13.37  2.00    Male     No   Sat  Dinner     2  0.175901     11.37
# 77        27.20  4.00    Male     No  Thur   Lunch     4  0.172414     23.20
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4  0.114233     27.05
# 76        17.92  3.08    Male    Yes   Sat  Dinner     2  0.207547     14.84
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2  0.350101      9.94

# %%
# Regressão:

reg = smf.ols('tip ~ net_bill', data = tips).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    tip   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.330
# Method:                 Least Squares   F-statistic:                     120.6
# Date:                Fri, 13 Oct 2023   Prob (F-statistic):           5.02e-23
# Time:                        08:43:24   Log-Likelihood:                -375.63
# No. Observations:                 244   AIC:                             755.3
# Df Residuals:                     242   BIC:                             762.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3307      0.168      7.907      0.000       0.999       1.662
# ...

# %%
# Reproduzindo o gráfico de dispersão

sns.regplot(y = 'tip', x = 'net_bill', data = tips[tips['tip_pct']<.5])

# Gerando dados para a linha dos 10%
x = np.linspace(0,tips['net_bill'].max(),100)
y = .1*x

# Plotando a linha dos 10%
plt.plot(x, y, '-r', label='linha dos 10%')

# Opções estéticas para explicitar o (0,0) no gráfico
plt.xlim(left = 0)
plt.ylim(bottom = 0)
# Out:
# (0.0, 10.5)

# %% [markdown]
# ### 2. Mudança de perspectiva
#
# Agora ajuste um modelo de regressão de ```tip_pct``` por ```net_bill```. Construa o gráfico de dispersão correspondente.

# %%
reg2 = smf.ols('tip_pct ~ net_bill', data = tips).fit()
reg2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                tip_pct   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     24.31
# Date:                Fri, 13 Oct 2023   Prob (F-statistic):           1.52e-06
# Time:                        09:09:03   Log-Likelihood:                 108.00
# No. Observations:                 244   AIC:                            -212.0
# Df Residuals:                     242   BIC:                            -205.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3053      0.023     13.166      0.000       0.260       0.351
# ...

# %%
sns.regplot(y = 'tip_pct', x = 'net_bill', data = tips[tips['tip_pct']<.5])

# Gerando dados para a linha dos 10%
x = np.linspace(0,tips['net_bill'].max())
y = 0.1


# Opções estéticas para explicitar o (0,0) no gráfico
plt.xlim(left = 0)
plt.ylim(bottom = 0)
# Out:
# (0.0, 0.505398619388979)

# %% [markdown]
# ### 3. Comente
#
# Compare os dois gráficos e comente (de forma objetiva e suscinta) a relação entre eles e a diferença do ajuste. Podemos comparar diretamente os $R^2$s?

# %% [markdown]
# --> Nesse caso, como o valor de y é a porcentagem, a inclinação (β do modelo) é negativa: y diminui conforme a x aumenta.
#
# O coeficiente de determinação do segundo é bem menor do que o primeiro.
#
# Mas não são comparáveis, por os modelos usam variáveis diferentes

# %% [markdown]
# ### 4. Ajuste do modelo em outra escala
#
# Com o modelo no item 3, obtenha a preditiva do valor da gorjeta:
#   1. obtenha o valor predito ```pred``` para ```tip_pct``` (dica, veja o atributo ```reg.fittedvalues```)
#   2. obtenha o valor predito para ```tip``` como ```tip_pct * net_bill```
#   3. calcule o $R^2$ do modelo para ```tip```
#   4. compare esse $R^2$ com o do item 1

# %%
# 1. Fazendo a preditiva de novos dados

tips['pct_pred'] = reg2.fittedvalues
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct  net_bill  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.063204     15.98
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.191244      8.68
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.199886     17.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.162494     20.37
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.172069     20.98
#
#    pct_pred
# 0  0.207087
# 1  0.251951
# 2  0.197684
# 3  0.180107
# 4  0.176358

# %%
# 2. Adicionando o valor predito de tip_pct * net_bill

tips['tip_pred'] = tips['pct_pred'] * tips['net_bill']
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct  net_bill  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.063204     15.98
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.191244      8.68
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.199886     17.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.162494     20.37
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.172069     20.98
# ..          ...   ...     ...    ...   ...     ...   ...       ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.256166     23.11
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.079428     25.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.096759     20.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.108899     16.07
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.190114     15.78
#
#      pct_pred  tip_pred
# ...

# %%
# 3. R² do modelo: entre o tip_pred e a tip real

tips[['tip_pred', 'tip']].corr().iloc[0,1]**2
# Out:
# 0.12112385704528729

# %%
# 4. 
tips[['tip_pct', 'pct_pred']].corr().iloc[0,1]**2
# Out:
# 0.0912908492066296

# %% [markdown]
# O R² para o valor predito da gorjeta é mais alto
